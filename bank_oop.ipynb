# %%
class Account:
    def __init__(self, owner, balance=0):
        if balance < 0:
            raise ValueError

        self.owner = owner
        self.balance = balance

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError
        self.balance += amount

    def withdraw(self, amount):
        if amount <= 0 or amount > self.balance:
            raise ValueError
        self.balance -= amount

    def get_balance(self):
        return f'Owner {self.owner}, Balance: {self.balance}'

# %%
andre = Account("Andre")

# %%
type(andre)
# Out:
# __main__.Account

# %%
andre.owner
# Out:
# 'Andre'

# %%
andre.balance
# Out:
# 0

# %%
ella = Account("Ella", 50)

# %%
type(ella)
# Out:
# __main__.Account

# %%
ella.owner
# Out:
# 'Ella'

# %%
ella.balance
# Out:
# 50

# %%
andre.deposit(1000)

# %%
andre.balance
# Out:
# 1000

# %%
ella.deposit(2000)

# %%
ella.balance
# Out:
# 2050

# %%
ella.withdraw(25)

# %%
ella.balance
# Out:
# 2025

# %%
ella.get_balance()
# Out:
# 'Owner Ella, Balance: 2025'

# %%
ella.balance
# Out:
# 2025

# %%
andre.get_balance()
# Out:
# 'Balance: 1000'
